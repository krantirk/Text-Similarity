# %%
#import libraries
import numpy as np
import pandas as pd
import pickle
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import pairwise_distances_argmin
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
#define a function to train the tdf vectorizer and store the model in a pickle file
def tfidf_features(X_train, X_test, vectorizer_path):
    """Performs TF-IDF transformation and dumps the model."""
    
    # Train a vectorizer on X_train data.
    # Transform X_train and X_test data.
    # Pickle the trained vectorizer to 'vectorizer_path'
    tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,1),min_df=5,max_df=0.95,token_pattern='(\S+)')
    X_train=  tfidf_vectorizer.fit_transform(X_train)
    X_test=tfidf_vectorizer.transform(X_test)
    fileObject = open(vectorizer_path,'wb') 
    pickle.dump(tfidf_vectorizer,fileObject)
    fileObject.close()
    return X_train, X_test

# %%
#load corpus data
corpus_df=pd.read_csv('data.csv',sep=',',header=0)

# %%
messages = list(corpus_df.iloc[:,2].values)

# %%
messages_id = list(corpus_df.iloc[:,1])

# %%
corpus_df
# Out:
#        Unnamed: 0                                               path  \
# 0               0  /ContentService/Books/Towards Infinity (Anant ...
# 1               1  /ContentService/Books/Towards Infinity (Anant ...
# 2               2  /ContentService/Books/Towards Infinity (Anant ...
# 3               3  /ContentService/Books/Towards Infinity (Anant ...
# 4               4  /ContentService/Books/Towards Infinity (Anant ...
# 5               5  /ContentService/Books/Towards Infinity (Anant ...
# 6               6  /ContentService/Books/Towards Infinity (Anant ...
# 7               7  /ContentService/Books/Towards Infinity (Anant ...
# 8               8  /ContentService/Books/Towards Infinity (Anant ...
# 9               9  /ContentService/Books/Towards Infinity (Anant ...
# 10             10  /ContentService/Books/Towards Infinity (Anant ...
# 11             11  /ContentService/Books/Towards Infinity (Anant ...
# 12             12  /ContentService/Books/Towards Infinity (Anant ...
# 13             13  /ContentService/Books/Towards Infinity (Anant ...
# 14             14  /ContentService/Books/Towards Infinity (Anant ...
# 15             15  /ContentService/Books/Towards Infinity (Anant ...
# 16             16  /ContentService/Books/Towards Infinity (Anant ...
# 17             17  /ContentService/Books/Towards Infinity (Anant ...
# 18             18  /ContentService/Books/Towards Infinity (Anant ...
# 19             19  /ContentService/Books/Towards Infinity (Anant ...
# 20             20  /ContentService/Books/Towards Infinity (Anant ...
# 21             21  /ContentService/Books/Towards Infinity (Anant ...
# 22             22  /ContentService/Books/Towards Infinity (Anant ...
# 23             23  /ContentService/Books/Towards Infinity (Anant ...
# 24             24  /ContentService/Books/Towards Infinity (Anant ...
# 25             25  /ContentService/Books/Towards Infinity (Anant ...
# 26             26  /ContentService/Books/Towards Infinity (Anant ...
# 27             27  /ContentService/Books/Towards Infinity (Anant ...
# 28             28  /ContentService/Books/Towards Infinity (Anant ...
# 29             29  /ContentService/Books/Towards Infinity (Anant ...
# ...           ...                                                ...
# 11984       11984  /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 11985       11985  /ContentService/Books/Test/ENGLISH/ADDRESS AT ...
# 11986       11986  /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 11987       11987  /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 11988       11988  /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 11989       11989  /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 11990       11990  /ContentService/Books/Test/ENGLISH/RELIGION NO...
# 11991       11991  /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 11992       11992  /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 11993       11993  /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 11994       11994  /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 11995       11995  /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 11996       11996  /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 11997       11997  /ContentService/Books/Test/ENGLISH/WHY WE DISA...
# 11998       11998  /ContentService/Books/Test/ENGLISH/WHY WE DISA...
# 11999       11999  /ContentService/Books/Test/ENGLISH/PAPER ON HI...
#
#split into train and test set (though we won't be using the test set)
x_train,x_test=train_test_split(corpus_df['content'].values.astype('U'), test_size=0.1, random_state=0)

# %%
#use train data to train the vectorizer and store in pickle file
x_train_tfidf, x_test_tfidf = tfidf_features(x_train, x_test, 'tfidf_vectorizer.pkl')

# %%
#load the search string
search_str=pd.read_csv('/Users/jnarayanan/Downloads/search.csv',sep=',',header=None)

# %%
#load the vectorizer from the pickle file
v = pickle.load(open('tfidf_vectorizer.pkl', 'rb'))

# %%
v
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.95, max_features=None, min_df=5,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(\\S+)', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
#convert search string to tfidf
search_tfidf=v.transform(search_str[0].values)

# %%
#convert corpus to tfidf
corpus_tfidf=v.transform(corpus_df['content'].values.astype('U'))

# %%
corpus_tfidf
# Out:
# <12014x13253 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1026295 stored elements in Compressed Sparse Row format>

# %%
#compute cosine similarity
y=cosine_similarity(corpus_tfidf,corpus_tfidf)

# %%
#sort the similarity matrix and get top five thrteads
t_vec=[-x[1] for x in y]
best_thread = np.argsort(t_vec)[1:6]

# %%
top_ind=y[0].argsort()[::-1][:6]

# %%
top_ind
# Out:
# array([    0,   460,   109, 10286,  5224,  7531], dtype=int64)

# %%
content = corpus_df['content']

# %%
content[best_thread]
# Out:
# 11908           Dear one, May you live long.  Blessings...
# 7531     Reply to My Letter from the Revered Mahatmaji ...
# 5292     Happy was the time when you saw me and happier...
# 7197     Letter to the Master with Diary for November, ...
# 8125     Deaths and births are happening everywhere and...
# Name: content, dtype: object

# %%
content[0]
# Out:
# 'Now I may throw some light on the state of consciousness which blooms after this first sub- point. When we cross this point to breathe in the next, everything seems to be changed. When we get merged into it a godly state begins to reign within and when identicality is developed we begin to feel that a peculiar state reflecting a tinge of divine touch prevails over all objects, animate and inanimate. There is such an indescribable outburst of emotional feelings at this point as often drives people, who lack the support of a worthy guru of calibre, to a state of mad ecstasy —  avadhuta — which keeps him entangled in it for ever, putting a permanent full stop to his onward advancement. Now let us ask those who boastfully profess to be the enlightened ones, or gyaani, whether they have ever come across such a state, which in fact is but the beginning of the first chapter of the book of knowledge. If we try to attain this state by applying our force of thought, it will only be artificial and not true and genuine. '

# %%
content[460]
# Out:
# 'The real state of enlightenment comes when we get into full consciousness of the condition of enlightenment, and after imbibing its effect secure our merging in it. When we develop this state and merge into its consciousness we come to know all about it and thus become gyaani, i.e., enlightened — up to that extent. If we try to gain the knowledge by applying our force of thought, it will only be artificial and not true and genuine. The real knowledge of a state means complete identicality with the state we have merged in. The help that knowledge at different states offers is that it infuses us with a longing for the search for the Ultimate. '

# %%
content[109]
# Out:
# 'The real knowledge of a state means complete identicality with the state we have merged in. It brings us to full consciousness of the condition and for this very reason it is interpreted as the real life which can be experienced only by an animate being. Being thus encouraged we now begin to aspire impatiently for further knowledge. '

# %%
content[10286]
# Out:
# "But something is essential for the abhyasi also. In the first place he must have full trust in the Master and must fully co-operate with him in every respect. If it is so he will positively go on developing day by day, and begin to feel himself changed and transformed. The state of waking consciousness of the lower type will get transformed, and his journey through higher and higher types of consciousness will be commenced. Usually consciousness is spoken of as of three levels: conscious, sub- conscious and super-conscious. They are however the broader divisions, and there are still innumerable levels of it in each one. The effect of the activities of the lower consciousness settles down upon the sub-conscious mind forming fate. The first thing to be undertaken is therefore the correction of the lower consciousness by right thinking and practice, so that it may itself be converted into force to bring the sub-conscious mind into a state of splendour. This brings us to the state of super-consciousness. If the word super- consciousness is modified as super-sub- consciousness I think it will be easier to understand its further effects. Anyhow, if by the Master's grace we have come up to it, another theme opens for us. We are in a way merged into it in order to bring to our view the aspects higher than this. The word 'higher' refers only to a rarefied state of it and in the same sense it is applied to the spiritual regions and spheres noted down in this connection. In short the various states of consciousness, one after the other, carry us along beyond the Trinity and even beyond Reality. The state of Freedom commences then but it is after a good deal of tiresome journey. When Freedom dawns the fatigue of the journey is over and we do not feel ourselves encumbered with its weight. "

# %%
dfObj = pd.DataFrame(columns = ['Main_Para_Id','Similar_Para_Id', 'Main_Para','Similar_Para', 'Similiarity_Index'])
#dfObj3 = pd.DataFrame(columns = ['Sent', 'Sent_Sim', 'Index_Sim'])
#df1 = pd.DataFrame([[1,2],], columns=['a','b'])

for i in tqdm(range(len(messages))):
#     x=corr[i,:];
#     print(x)
    top_ind=y[i].argsort()[::-1][:6]
#     print(top_ind)
    for j in range(1,6):
        a= messages_id[i]
        b= messages_id[top_ind[j]]
        c=messages[i]
#         print(a)
        d=messages[top_ind[j]]
#         print(b)
        e=y[i,top_ind[j]]
        #print(c)
#         print(dfObj)
        #print (a,b,c)
        #df1 = pd.DataFrame([[1,2],], columns=['a','b'])
        #print(a,b,c,d,e)
        dfObj2 = pd.DataFrame( [[a, b, c,d,e],], columns =['Main_Para_Id','Similar_Para_Id', 'Main_Para','Similar_Para', 'Similiarity_Index'])
        #print(dfObj2)
        dfObj=dfObj.append(dfObj2)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 12014/12014 [04:28<00:00, 44.80it/s]

# %%
from tqdm import tqdm

# %%
dfObj
# Out:
#                                          Main_Para_Id  \
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# ..                                                ...
# 0   /ContentService/Books/Test/ENGLISH/RELIGION NO...
# 0   /ContentService/Books/Test/ENGLISH/RELIGION NO...
# 0   /ContentService/Books/Test/ENGLISH/RELIGION NO...
# 0   /ContentService/Books/Test/ENGLISH/RELIGION NO...
# 0   /ContentService/Books/Test/ENGLISH/RELIGION NO...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/WHY WE DISA...
# 0   /ContentService/Books/Test/ENGLISH/WHY WE DISA...
# 0   /ContentService/Books/Test/ENGLISH/WHY WE DISA...
# 0   /ContentService/Books/Test/ENGLISH/WHY WE DISA...
# 0   /ContentService/Books/Test/ENGLISH/WHY WE DISA...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
#
#                                       Similar_Para_Id  \
# 0   /ContentService/Books/Sahaj Marg Philosophy/EN...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Voice Real - The Second ...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Truth Eternal/ENGLISH/Br...
# 0   /ContentService/Books/Truth Eternal/ENGLISH/Sp...
# 0   /ContentService/Books/Truth Eternal/ENGLISH/Qu...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Commentary on Ten Maxims...
# 0   /ContentService/Books/Truth Eternal/ENGLISH/Pu...
# 0   /ContentService/Books/Towards Infinity (Anant ...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Voice Real - The First S...
# ..                                                ...
# 0   /ContentService/Books/Test/ENGLISH/ADDRESS AT ...
# 0   /ContentService/Books/Test/ENGLISH/WHY WE DISA...
# 0   /ContentService/Books/Test/ENGLISH/BUDDHISM, T...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/RESPONSE TO...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Reality At Dawn/ENGLISH/...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/The Efficacy of Raja Yog...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Autobiography of Ram Cha...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Voice Real - The Second ...
# 0   /ContentService/Books/Truth Eternal/ENGLISH/Ig...
# 0   /ContentService/Books/Voice Real - The First S...
# 0   /ContentService/Books/The Story of Divine Revo...
# 0   /ContentService/Books/Sahaj Marg Philosophy/EN...
# 0   /ContentService/Books/Complete Works of Ram Ch...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Truth Eternal/ENGLISH/Ka...
# 0   /ContentService/Books/Test/ENGLISH/PAPER ON HI...
# 0   /ContentService/Books/Truth Eternal/ENGLISH/Ex...
#
#                                             Main_Para  \
# 0   Now I may throw some light on the state of con...
# 0   Now I may throw some light on the state of con...
# 0   Now I may throw some light on the state of con...
# 0   Now I may throw some light on the state of con...
# 0   Now I may throw some light on the state of con...
# 0   Briefly here I may add that the feeling of  ah...
# 0   Briefly here I may add that the feeling of  ah...
# 0   Briefly here I may add that the feeling of  ah...
# 0   Briefly here I may add that the feeling of  ah...
# 0   Briefly here I may add that the feeling of  ah...
# 0   This state is attainable after thousands of ye...
# 0   This state is attainable after thousands of ye...
# 0   This state is attainable after thousands of ye...
# 0   This state is attainable after thousands of ye...
# 0   This state is attainable after thousands of ye...
# 0   The same exactly is true about this nucleus to...
# 0   The same exactly is true about this nucleus to...
# 0   The same exactly is true about this nucleus to...
# 0   The same exactly is true about this nucleus to...
# 0   The same exactly is true about this nucleus to...
# 0   We have to arrive at the real thing which is u...
# 0   We have to arrive at the real thing which is u...
# 0   We have to arrive at the real thing which is u...
# 0   We have to arrive at the real thing which is u...
# 0   We have to arrive at the real thing which is u...
# 0   Shri Ram Chandraji Maharaj is one of the forem...
# 0   Shri Ram Chandraji Maharaj is one of the forem...
# 0   Shri Ram Chandraji Maharaj is one of the forem...
# 0   Shri Ram Chandraji Maharaj is one of the forem...
# 0   Shri Ram Chandraji Maharaj is one of the forem...
# ..                                                ...
# 0                               20th September, 1893
# 0                               20th September, 1893
# 0                               20th September, 1893
# 0                               20th September, 1893
# 0                               20th September, 1893
# 0   Whatever may be the position of philosophy, wh...
# 0   Whatever may be the position of philosophy, wh...
# 0   Whatever may be the position of philosophy, wh...
# 0   Whatever may be the position of philosophy, wh...
# 0   Whatever may be the position of philosophy, wh...
# 0        That has been the difficulty all the while.
# 0        That has been the difficulty all the while.
# 0        That has been the difficulty all the while.
# 0        That has been the difficulty all the while.
# 0        That has been the difficulty all the while.
# 0   It is good to love God for hope of reward in t...
# 0   It is good to love God for hope of reward in t...
# 0   It is good to love God for hope of reward in t...
# 0   It is good to love God for hope of reward in t...
# 0   It is good to love God for hope of reward in t...
# 0   The religion of the Hindus is divided into two...
# 0   The religion of the Hindus is divided into two...
# 0   The religion of the Hindus is divided into two...
# 0   The religion of the Hindus is divided into two...
# 0   The religion of the Hindus is divided into two...
# 0   So then the Hindu believes that he is a spirit...
# 0   So then the Hindu believes that he is a spirit...
# 0   So then the Hindu believes that he is a spirit...
# 0   So then the Hindu believes that he is a spirit...
# 0   So then the Hindu believes that he is a spirit...
#
#                                          Similar_Para  Similiarity_Index
# 0   The real state of enlightenment comes when we ...           0.394180
# 0   The real knowledge of a state means complete i...           0.312557
# 0   But something is essential for the abhyasi als...           0.308624
# 0   Comparing the spiritual state of an advanced m...           0.295749
# 0   Reply to My Letter from the Revered Mahatmaji ...           0.292491
# 0          Dear one, May you live long.  Blessings...           0.313344
